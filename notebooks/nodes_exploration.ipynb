# %%
import networkx as nx
import pandas as pd
import ast
from dateutil import parser

# %%
nodes = pd.read_csv("../out/nikhilarundesai/nodes.csv")

# %%
# Which people that I follow simply don't tweet much?
nodes[nodes["statuses_count"] < 10]
# Out:
#                       Id                                           name  \
# 222           2518284630                                        Ash Ngu
# 297             70784623                                    Lizzie Wade
# 541             12229772                                    Chris Coyne
# 870           1563646128                                     Geena Chen
# 872            176626752                                    Deepa Varma
# 879           3346224705                                    Alex Emmons
# 1080            24311459                                       jay moon
# 1104           237099368                                     Cora Lewis
# 1110          2363507635                               Rahul Singireddy
# 1172           217147972                           Ofeibea Quist-Arcton
# 1339           201133168                                 Keenan Pontoni
# 1467  850765554914795521                                      Tyler Dec
# ...

# %%
# See if I can figure out how to identify an account that hasn't tweeted in a long time.
print(nodes.iloc[1842]["status"])
# Can't parse this to JSON for some reason
# Out:
# {'created_at': 'Mon Jun 08 20:36:04 +0000 2009', 'id': 2080872712, 'id_str': '2080872712', 'text': 'Chris Moylan will be a guest on the KKUP 91.5 FM morning show this Wed., June 10th at 7AM.\n\nListen in and give Chris a call 408-260-2999', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}

# %%
def parse_datetime(status):
    try:
        eval_result = ast.literal_eval(status)
    except:
        return None

    if 'created_at' in eval_result:
        return parser.parse(eval_result['created_at'])
    else:
        return None

nodes["last_tweet_time"] = nodes["status"].map(lambda s: parse_datetime(s))

# %%
nodes.sort_values(by='last_tweet_time').head(50)
# Out:
#                       Id                  name      screen_name  \
# 1842            26274892          Chris Moylan      moylanforcc
# 2269           134852921         Sean Elsbernd     SeanElsbernd
# 4678            72961596         Stanford Arts     StanfordSOCA
# 4892            68522681         Anjan B Katta      anjanBkatta
# 2612            26837501      Michael Goldfarb      thegoldfarb
# 4937            14180440         Paul Tulipana        ptulipana
# 3672           107106071           Bill Halter       BillHalter
# 4602            77436450               Tebello      Qhotsokoane
# 4579            14351053       United Republic        unitedrep
# 4540           394834584          Mikael Meyer      mikaelmeyer
# 4836          2566463630              EzBakeIO         EzBakeIO
# 1478           263529045            Gulf Wild™         GulfWild
# 4941           577698733            Victor Eng       victoraeng
# 4522          1107249546         Chan Chi Ling    callmechiling
# ...

# %%
nodes.sort_values(by='last_tweet_time')[50:100]
# Out:
#                       Id                  name      screen_name  \
# 4613          1856564016          Jeewan Hathi  ZindaBhaagMovie
# 4501           381805342                  BACC   BayAreaClimate
# 4528          2716645106   Type Theory Podcast  typetheorypcast
# 3737          2749218067   PERC Enviropreneurs   enviropreneurs
# 2737            89521629            Roman Reed   spinalcordcure
# 3613  757824938791227392               WeRally       werallyapp
# 4455            48847646       $pread Magazine        spreadmag
# 4576            15442036    Sen. Barbara Boxer     SenatorBoxer
# 4469          1075634107    Aishu Venkataraman    divinestrings
# 3834          4182682165           Sohag Desai          drswago
# 4401            24752484       Open Gov (NARA)        OpenGov44
# 4820           113420831  J Earnest (Archived)       PressSec44
# 4338          2695663285         Julián Castro  SecretaryCastro
# 4165           325830217   VP Biden (Archived)             VP44
# ...

# %%
nodes.sort_values(by='last_tweet_time')[100:150]
# Out:
#                       Id                                               name  \
# 4970            42955608                                       Stanford ACM
# 1107  765656451066978304                                  Google Code Corps
# 3408          2383869739                                   Workers' Project
# 380   845482631689093121                                     Bhargava Manja
# 4835            96830862                                Mohammad Shahangian
# 3135            18451200                                        POLITICO 45
# 4092            82687751                                  Judge Don Willett
# 1637            81690879                                    Carbon War Room
# 1079  712870666530328576                                             At Bay
# 2911            30694631  Ursus, Director of Weather and Banana Programming
# 3030  793800710433411073                                     OxEtruscologia
# ...

# %%
nodes.sort_values(by='last_tweet_time')[150:200]
# Out:
#                       Id                     name      screen_name  \
# 816            192224833              Andy Miller        _amiller_
# 3139           805917350  Elizabeth Mann Levesque        elizkmann
# 3376            85634177      Politics in America       cqprofiles
# 3991           274309704            Mitch Brodsky     mitchbrodsky
# 3496           463132556  Former Rep. Jared Polis    RepJaredPolis
# 2229            86877264               Jeff Rosen       Jeff_Rosen
# 2637  809194450840911874           TechSolidarity   TechSolidarity
# 4213          3514310897                 Alluvium         alluvium
# 2282  803237155275472896             Daily Action  YourDailyAction
# 2445            14191640            Stuart Geiger          staeiou
# 2244  796508293078405120       Trump Just Googled    usagovgoogles
# 2266  777893334316613632            First Mondays   FirstMondaysFM
# 3996          2335752644                   Wunder    WunderCapital
# ...

# %%
nodes.sort_values(by='last_tweet_time')[200:250]
# Out:
#                        Id                          name      screen_name  \
# 4216   705121898800267264              Harvard Life Lab   harvardlifelab
# 4041             66336739                  BBC Election      bbcelection
# 1479             71821409                  Palko Karasz      karaszpalko
# 2205           2193259544               AG Mark Herring    AGMarkHerring
# 4519           2999876456              Erowid Recruiter  erowidrecruiter
# 4229           2400039685                 UCL THIN Team         ucl_thin
# 848             349563958              Hanif Zarrabi-K.          hanifzk
# 3689           3107968693          Circle of Protection          TheCofP
# 3888           2813605170                 Sidewire Inc.      sidewireinc
# 2610             56011700          Randy Newberg Hunter     randynewberg
# 1633             65322179                   Open Europe       OpenEurope
# 4870           2593194452                     Gautam Hx     GautamAtWork
# ...

# %%
nodes.sort_values(by='last_tweet_time')[250:300]
# Out:
#                       Id                  name      screen_name  \
# 2076           800224278           Shadow Wars   tbijshadowwars
# 3654           459572997            Jim Snyder       JimNews3LV
# 4303          2338702590  Cong. Data Coalition     congressdata
# 4707            15521760         Chris Watkins  chris_watkins93
# 1476           237019529             Good Food     KCRWGoodFood
# 2082  764243813330145280         Bill Harrison  BillHarrisonCPA
# 2671          2402197177         Arctic Deeply     ArcticDeeply
# 4002             8128442            Mark Udall        MarkUdall
# 1930            16613134       JoesUnionReview  JoesUnionReview
# 2170            27905110            Joe Nation        joenation
# 3750  759964421443637249      538 Forecast Bot   538forecastbot
# 938            385423407         Tobias Basuki     TobiasBasuki
# 2009           393604413      Andrew Mazibrada   meridianscribe
# 1873          1903784376          Timofey Pnin         pnin1957
# ...
